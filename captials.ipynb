# %%
# !pip install pyTelegramBotAPI
# !pip install openapi
# !pip install pycountry
# !pip install geonamescache
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 17.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681831 sha256=9dd9b2001c0f383ceed47116242a01e2a6b421c47d5868cdaad75fcaf5f222af
#   Stored in directory: /root/.cache/pip/wheels/03/57/cc/290c5252ec97a6d78d36479a3c5e5ecc76318afcb241ad9dbe
# Successfully built pycountry
# ...

# %%
import telebot
import pycountry
from geonamescache import GeonamesCache

API_TOKEN = '6595333472:AAEIpbMXxqX5a7twZI633oatAqUneBrfWK0'
bot = telebot.TeleBot(API_TOKEN)
gc = GeonamesCache()

countries_capitals = {
    'Google': 'Sundar pichai',
    'Microsoft': 'satya nadella',
    'Amazon': 'Andy Jassy',
    'Apple': 'Tim Cook',
    'Facebook': 'Mark Zuckerberg',
    'Twitter': 'Linda Yaccarino',
    'IndianServers':'Sai Sateesh',
    # Add more countries and capitals here
}

@bot.message_handler(commands=['start', 'help'])
def send_welcome(message):
    bot.reply_to(message, "Welcome! Send me the name of a Company, and I'll tell you its Ceo.")

@bot.message_handler(func=lambda message: True)
def echo_all(message):
    country_names = message.text.split(',')
    print(message)
    capitals = []
    for country_name in country_names:
        country_name = country_name.strip()
        capital = countries_capitals.get(country_name, "Not found")
        capitals.append((country_name, capital))

    response = "\n".join([f"The Ceo of {country} is {capital}." for country, capital in capitals])
    bot.reply_to(message, response)
bot.polling()
# Out:
# {'content_type': 'text', 'id': 93, 'message_id': 93, 'from_user': {'id': 726498616, 'is_bot': False, 'first_name': 'Aravind', 'username': 'Aravind1922y', 'last_name': 'K', 'language_code': 'en', 'can_join_groups': None, 'can_read_all_group_messages': None, 'supports_inline_queries': None, 'is_premium': None, 'added_to_attachment_menu': None}, 'date': 1692552938, 'chat': {'id': 726498616, 'type': 'private', 'title': None, 'username': 'Aravind1922y', 'first_name': 'Aravind', 'last_name': 'K', 'is_forum': None, 'photo': None, 'bio': None, 'join_to_send_messages': None, 'join_by_request': None, 'has_private_forwards': None, 'has_restricted_voice_and_video_messages': None, 'description': None, 'invite_link': None, 'pinned_message': None, 'permissions': None, 'slow_mode_delay': None, 'message_auto_delete_time': None, 'has_protected_content': None, 'sticker_set_name': None, 'can_set_sticker_set': None, 'linked_chat_id': None, 'location': None, 'active_usernames': None, 'emoji_status_custom_
# ...
